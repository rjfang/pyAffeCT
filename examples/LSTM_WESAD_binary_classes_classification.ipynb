# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import sys
import os
sys.path.append(os.path.abspath('/content/drive/MyDrive/02 Research/01 Affective Computing/03 Benchmark/'))
try:
    import neurokit2
except ImportError as e:
    # !pip install neurokit2

try:
    import pyedflib
except ImportError as e:
    # !pip install pyedflib

try:
    import tpot
except ImportError as e:
    # !pip install tpot

# %% [markdown]
# # Dataset

# %%
from pyAffeCT.datasets import WESAD

wesad = WESAD(os.path.abspath('/content/drive/MyDrive/02 Research/01 Affective Computing/03 Benchmark/pyAffeCT/data/WESAD'))

# view the subject id list
subject_list = wesad.subject_list

num_classes = 2

# prepare for the dataframe, set number of classess to be 3
df_train, df_test = wesad.prepare_flatten_dataframe(subject_included=subject_list[:3], split_by_subject=False, window_length=4,num_classes=num_classes)

train_loader, test_loader, input_shape = wesad.df_to_dataloader(df_train,df_test,num_classes, 4)
# Out:
# 100%|██████████| 3/3 [05:27<00:00, 109.17s/it]

# %%
train_loader, test_loader, input_shape = wesad.df_to_dataloader(df_train,df_test,num_classes, 4)

# %% [markdown]
# # Model

# %%
from pyAffeCT.models import LSTM

input_shape=input_shape
net = LSTM(input_shape = input_shape, num_classes=num_classes)
net.init_weights(method=None)

# %% [markdown]
# # Train

# %%
net.train(train_loader, test_loader)
# Out:
# Epoch [1/100],  Loss: 0.6655
# Accuracy of the network on the test data: 64.706 %
# Epoch [2/100],  Loss: 0.6113
# Accuracy of the network on the test data: 63.603 %
# Epoch [3/100],  Loss: 0.5724
# Accuracy of the network on the test data: 63.235 %
# Epoch [4/100],  Loss: 0.5752
# Accuracy of the network on the test data: 63.235 %
# Epoch [5/100],  Loss: 0.5618
# Accuracy of the network on the test data: 62.868 %
# Epoch [6/100],  Loss: 0.5563
# Accuracy of the network on the test data: 63.603 %
# Epoch [7/100],  Loss: 0.5459
# Accuracy of the network on the test data: 64.338 %
# Epoch [8/100],  Loss: 0.5397
# Accuracy of the network on the test data: 63.971 %
# Epoch [9/100],  Loss: 0.5226
# Accuracy of the network on the test data: 65.074 %
# Epoch [10/100],  Loss: 0.4963
# Accuracy of the network on the test data: 66.176 %
# Epoch [11/100],  Loss: 0.4886
# Accuracy of the network on the test data: 65.809 %
# Epoch [12/100],  Loss: 0.4811

# %%
net.test_accuracy(test_loader)
